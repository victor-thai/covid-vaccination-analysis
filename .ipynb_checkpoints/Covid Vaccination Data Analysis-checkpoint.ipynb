# %% [markdown]
# # Covid Vaccination Data Analysis
# August 28, 2022 Victor Thai
#
# https://covid.cdc.gov/covid-data-tracker/#datatracker-home
#
# https://ourworldindata.org/covid-vaccinations

# %%
# import dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import dataset
vaccinations = pd.read_csv('vaccinations_manufacturer.txt')
vaccination_rate = pd.read_csv('vaccinations.txt')

# %%
vaccination_rate
# Out:
#            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 126108     Zimbabwe      ZWE  2022-09-04                 NaN
# 126109     Zimbabwe      ZWE  2022-09-05                 NaN
# 126110     Zimbabwe      ZWE  2022-09-06                 NaN
# 126111     Zimbabwe      ZWE  2022-09-07                 NaN
# 126112     Zimbabwe      ZWE  2022-09-08          12161598.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# ...

# %%
vaccinations.head()
# Out:
#     location        date             vaccine  total_vaccinations
# 0  Argentina  2020-12-29  Oxford/AstraZeneca                   1
# 1  Argentina  2020-12-29   Sinopharm/Beijing                   1
# 2  Argentina  2020-12-29           Sputnik V               20487
# 3  Argentina  2020-12-30           Sputnik V               40589
# 4  Argentina  2020-12-31           Sputnik V               43395

# %%
# statistical data information
vaccinations.describe()
# Out:
#        total_vaccinations
# count        4.510100e+04
# mean         2.154980e+07
# std          6.478526e+07
# min          0.000000e+00
# 25%          2.577810e+05
# 50%          2.058319e+06
# 75%          1.283159e+07
# max          6.303310e+08

# %%
# countries that have the highest vaccination numbers
vaccinations.groupby('location').sum().sort_values('total_vaccinations', ascending = False).head(10)
# Out:
#                 total_vaccinations
# location
# European Union        335198232892
# United States         187208078657
# Japan                  95649415462
# Germany                68675543266
# France                 54604110190
# Italy                  48820464376
# South Korea            39852951478
# Argentina              34908135300
# Peru                   22087892878
# Chile                  15182285305

# %%
country_group.reset_index()
# Out:
#           location  total_vaccinations
# 0        Argentina         34908135300
# 1          Austria          1112709993
# 2          Belgium          1386225707
# 3         Bulgaria           224073790
# 4           Canada          3380362151
# 5            Chile         15182285305
# 6          Croatia           319978878
# 7           Cyprus            88579763
# 8          Czechia          6878555298
# 9          Denmark           688033619
# 10         Ecuador          4597354833
# 11         Estonia           111625247
# 12  European Union        335198232892
# 13         Finland           651572456
# 14          France         54604110190
# 15         Germany         68675543266
# 16       Hong Kong          5440068018
# 17         Hungary           909666370
# 18         Iceland             4372361
# 19         Ireland           661970961
# 20           Italy         48820464376
# 21           Japan         95649415462
# 22          Latvia           855246184
# ...

# %%
# plot of countries with highest vaccination numbers
country_group = vaccinations.groupby('location')['total_vaccinations'].sum().reset_index().sort_values('total_vaccinations', ascending = False).head(10)
sns.barplot(x = 'location', y = 'total_vaccinations', data = country_group)
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_vaccinations'>

# %%
vaccinations['location'].unique()
# Out:
# array(['Argentina', 'Austria', 'Belgium', 'Bulgaria', 'Canada', 'Chile',
#        'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Ecuador', 'Estonia',
#        'Finland', 'France', 'Germany', 'Hong Kong', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Latvia', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Malta', 'Nepal', 'Netherlands',
#        'Norway', 'Peru', 'Poland', 'Portugal', 'Romania', 'Slovakia',
#        'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'Ukraine', 'United States', 'Uruguay',
#        'European Union'], dtype=object)

# %% [markdown]
# As we look at the top 10 highest total number of vaccinations by country, the EU, US, and Japan are the highest. While we plot our data, the EU has nearly double the total vaccinations of the United States. On top of that, the United States has roughly twice as many total vaccinations as Japan. Overall, the EU has been a top vaccinator for its people.
#
# Looking into why the EU has such a high vaccination number, it must be known that there are countries that are listed independently in our data to also be counted towards the total of the EU location group.
#
# As of August 28, 2022, the countries in our dataset that are also apart of the EU are:
# - Austria
# - Belgium
# - Croatia
# - Cyprus
# - Czech
# - Denmark
# - Estonia
# - Finland
# - France
# - Germany
# - Hungary
# - Ireland
# - Italy
# - Latvia
# - Lithuania
# - Malta
# - Netherlands
# - Poland
# - Portugal
# - Romania
# - Slovakia
# - Slovenia
# - Spain
# - Sweden
#
# Thus, most of our countries listed in the dataset is already apart of the EU.

# %%
# look at which vaccine is most popular
vaccinations.groupby('vaccine')['total_vaccinations'].sum().sort_values(ascending = False)
# Out:
# vaccine
# Pfizer/BioNTech       648889711526
# Moderna               189135754779
# Oxford/AstraZeneca     64805703557
# Sinopharm/Beijing      20878679455
# Johnson&Johnson        19833688277
# Sinovac                18483518968
# Sputnik V               9462160704
# CanSino                  256132767
# Novavax                  172326774
# Covaxin                      38856
# Medicago                      2235
# Name: total_vaccinations, dtype: int64

# %% [markdown]
# As we look into which vaccine is most popular among all people that are vaccinated, we can see that Pfizer, Moderna, and AstraZeneca are the most widely used among all countries.

# %%
# look into which vaccine is most popular among each country
country_vaccine = vaccinations.groupby(['location','vaccine']).sum().sort_values(['location', 'total_vaccinations'], ascending = [True, False]).reset_index()
country_vaccine_popular = country_vaccine.groupby('location').first()
country_vaccine_popular
# Out:
#                           vaccine  total_vaccinations
# location
# Argentina       Sinopharm/Beijing         10435802957
# Austria           Pfizer/BioNTech           879788892
# Belgium           Pfizer/BioNTech          1013522736
# Bulgaria          Pfizer/BioNTech           153284664
# Canada            Pfizer/BioNTech          2352820770
# Chile                     Sinovac         11550207016
# Croatia           Pfizer/BioNTech           241723905
# Cyprus            Pfizer/BioNTech            68045894
# Czechia           Pfizer/BioNTech          5880208578
# Denmark           Pfizer/BioNTech           582998326
# Ecuador                   Sinovac          2561770670
# Estonia           Pfizer/BioNTech            83303819
# European Union    Pfizer/BioNTech        243477686465
# Finland           Pfizer/BioNTech           534059404
# France            Pfizer/BioNTech         43876459783
# Germany           Pfizer/BioNTech         51847810991
# ...

# %%
# most popular vaccine among other popular vaccines in other countries
country_vaccine_popular.value_counts('vaccine')
# Out:
# vaccine
# Pfizer/BioNTech      38
# Moderna               2
# Sinopharm/Beijing     2
# Sinovac               2
# dtype: int64

# %% [markdown]
# Through our analysis, Pfizer seems to be the vaccine that dominates over all the other popular vaccines in other countries.
